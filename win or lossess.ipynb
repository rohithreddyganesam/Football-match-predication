# %%
import pandas as pd
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score
from sklearn.metrics import precision_score

# %%
matches = pd.read_csv("matches_2.csv", index_col=0)
matches
# Out:
#           date   time            comp         round  day venue result  gf  ga  \
# 1   07-08-2022  16:30  Premier League   Matchweek 1  Sun  Away      W   2   0
# 2   13-08-2022  15:00  Premier League   Matchweek 2  Sat  Home      W   4   0
# 3   21-08-2022  16:30  Premier League   Matchweek 3  Sun  Away      D   3   3
# 4   27-08-2022  15:00  Premier League   Matchweek 4  Sat  Home      W   4   2
# 5   31-08-2022  19:30  Premier League   Matchweek 5  Wed  Home      W   6   0
# ..         ...    ...             ...           ...  ...   ...    ...  ..  ..
# 38  07-07-2020  18:00  Premier League  Matchweek 34  Tue  Home      W   2   1
# 39  11-07-2020  12:30  Premier League  Matchweek 35  Sat  Home      W   2   1
# 40  17-07-2020  20:00  Premier League  Matchweek 36  Fri  Away      L   1   3
# 41  21-07-2020  18:00  Premier League  Matchweek 37  Tue  Home      L   0   4
# 42  26-07-2020  16:00  Premier League  Matchweek 38  Sun  Away      L   2   3
#
#            opponent  ...          referee  match report  sh  sot  dist fk pk  \
# 1          West Ham  ...   Michael Oliver  Match Report  13    1  18.7  1  1
# 2       Bournemouth  ...      David Coote  Match Report  19    7  17.5  0  0
# 3     Newcastle Utd  ...   Jarred Gillett  Match Report  21   10  16.2  1  0
# 4    Crystal Palace  ...   Darren England  Match Report  18    5  14.1  0  0
# 5   Nott'ham Forest  ...     Paul Tierney  Match Report  17    9  14.8  0  0
# ..              ...  ...              ...           ...  ..  ...   ... .. ..
# 38     Norwich City  ...   Anthony Taylor  Match Report   9    4  13.2  0  0
# 39    Newcastle Utd  ...     Craig Pawson  Match Report  15    3  13.9  0  2
# 40         West Ham  ...  Martin Atkinson  Match Report  14    3  14.9  0  0
# 41  Manchester City  ...   Michael Oliver  Match Report   2    0  15.7  0  0
# 42          Arsenal  ...        Mike Dean  Match Report  18    5  13.7  1  1
#
#    pkatt  season             team
# 1      1    2023  Manchester City
# 2      0    2023  Manchester City
# 3      0    2023  Manchester City
# 4      0    2023  Manchester City
# 5      0    2023  Manchester City
# ..   ...     ...              ...
# 38     0    2020          Watford
# 39     2    2020          Watford
# 40     0    2020          Watford
# 41     0    2020          Watford
# 42     1    2020          Watford
#
# [3002 rows x 26 columns]

# %%
matches.shape
# Out:
# (3002, 26)

# %%
matches["team"].value_counts()
# Out:
# Manchester City             152
# Crystal Palace              152
# Southampton                 152
# Leicester City              152
# Everton                     152
# West Ham United             152
# Arsenal                     152
# Chelsea                     152
# Wolverhampton Wanderers     152
# Tottenham Hotspur           152
# Aston Villa                 152
# Brighton and Hove Albion    152
# Liverpool                   152
# Newcastle United            152
# Manchester United           152
# Leeds United                114
# Burnley                     114
# Fulham                       76
# Brentford                    76
# Bournemouth                  76
# Watford                      76
# Sheffield United             76
# Nottingham Forest            38
# Norwich City                 38
# West Bromwich Albion         38
# Name: team, dtype: int64

# %%
matches[matches["team"] == "Liverpool"].sort_values("date")
# Out:
#           date   time            comp         round  day venue result  gf  ga  \
# 37  01-02-2020  15:00  Premier League  Matchweek 25  Sat  Home      W   4   0
# 36  01-03-2023  20:00  Premier League   Matchweek 7  Wed  Home      W   2   0
# 40  01-04-2023  12:30  Premier League  Matchweek 29  Sat  Away      L   1   4
# 9   01-10-2022  15:00  Premier League   Matchweek 9  Sat  Home      D   3   3
# 20  01-12-2021  20:15  Premier League  Matchweek 14  Wed  Away      W   4   1
# ..         ...    ...             ...           ...  ...   ...    ...  ..  ..
# 24  30-12-2022  20:00  Premier League  Matchweek 18  Fri  Home      W   2   1
# 31  31-01-2021  16:30  Premier League  Matchweek 21  Sun  Away      W   3   1
# 5   31-08-2019  17:30  Premier League   Matchweek 4  Sat  Away      W   3   0
# 5   31-08-2022  20:00  Premier League   Matchweek 5  Wed  Home      W   2   1
# 11  31-10-2020  17:30  Premier League   Matchweek 7  Sat  Home      W   2   1
#
#            opponent  ...         referee  match report  sh  sot  dist fk pk  \
# 37      Southampton  ...    Kevin Friend  Match Report  16    9  15.0  1  0
# 36           Wolves  ...    Paul Tierney  Match Report  15    6  13.6  0  0
# 40  Manchester City  ...    Simon Hooper  Match Report   4    1  15.9  0  0
# 9          Brighton  ...     Andy Madley  Match Report  15    7  16.8  1  0
# 20          Everton  ...    Paul Tierney  Match Report  16    7  16.5  1  0
# ..              ...  ...             ...           ...  ..  ...   ... .. ..
# 24   Leicester City  ...    Craig Pawson  Match Report  21    5  18.4  1  0
# 31         West Ham  ...   Jonathan Moss  Match Report  14    5  15.7  0  0
# 5           Burnley  ...  Chris Kavanagh  Match Report  15    7  21.0  0  0
# 5     Newcastle Utd  ...  Andre Marriner  Match Report  23    6  17.8  0  0
# 11         West Ham  ...    Kevin Friend  Match Report   8    4  20.0  1  1
#
#    pkatt  season       team
# 37     0    2020  Liverpool
# 36     0    2023  Liverpool
# 40     0    2023  Liverpool
# 9      0    2023  Liverpool
# 20     0    2022  Liverpool
# ..   ...     ...        ...
# 24     0    2023  Liverpool
# 31     0    2021  Liverpool
# 5      0    2020  Liverpool
# 5      0    2023  Liverpool
# 11     1    2021  Liverpool
#
# [152 rows x 26 columns]

# %%
matches["round"].value_counts()
# Out:
# Matchweek 1     79
# Matchweek 30    79
# Matchweek 23    79
# Matchweek 12    79
# Matchweek 24    79
# Matchweek 25    79
# Matchweek 26    79
# Matchweek 27    79
# Matchweek 29    79
# Matchweek 31    79
# Matchweek 2     79
# Matchweek 33    79
# Matchweek 34    79
# Matchweek 28    79
# Matchweek 35    79
# Matchweek 36    79
# Matchweek 37    79
# Matchweek 32    79
# Matchweek 22    79
# Matchweek 21    79
# Matchweek 7     79
# Matchweek 20    79
# Matchweek 3     79
# Matchweek 4     79
# Matchweek 5     79
# Matchweek 6     79
# Matchweek 8     79
# Matchweek 9     79
# Matchweek 10    79
# Matchweek 11    79
# Matchweek 13    79
# Matchweek 14    79
# Matchweek 15    79
# Matchweek 16    79
# Matchweek 17    79
# Matchweek 18    79
# Matchweek 19    79
# Matchweek 38    79
# Name: round, dtype: int64

# %%
matches.dtypes
# Out:
# date             object
# time             object
# comp             object
# round            object
# day              object
# venue            object
# result           object
# gf                int64
# ga                int64
# opponent         object
# xg              float64
# xga             float64
# poss              int64
# attendance      float64
# captain          object
# formation        object
# referee          object
# match report     object
# sh                int64
# sot               int64
# dist            float64
# fk                int64
# pk                int64
# pkatt             int64
# season            int64
# team             object
# dtype: object

# %%
del matches["comp"]

# %%
matches["date"] = pd.to_datetime(matches["date"])
# Out:
# C:\Users\grohi\AppData\Local\Temp\ipykernel_11960\2174778740.py:1: UserWarning: Parsing dates in DD/MM/YYYY format when dayfirst=False (the default) was specified. This may lead to inconsistently parsed dates! Specify a format to ensure consistent parsing.
#   matches["date"] = pd.to_datetime(matches["date"])

# %%
matches["target"] = (matches["result"] == "W").astype("int")
matches["target_2"] = (matches["result"] == "D").astype("int")
matches["target_3"] = (matches["result"] == "L").astype("int")

# %%
matches
# Out:
#          date   time         round  day venue result  gf  ga         opponent  \
# 1  2022-07-08  16:30   Matchweek 1  Sun  Away      W   2   0         West Ham
# 2  2022-08-13  15:00   Matchweek 2  Sat  Home      W   4   0      Bournemouth
# 3  2022-08-21  16:30   Matchweek 3  Sun  Away      D   3   3    Newcastle Utd
# 4  2022-08-27  15:00   Matchweek 4  Sat  Home      W   4   2   Crystal Palace
# 5  2022-08-31  19:30   Matchweek 5  Wed  Home      W   6   0  Nott'ham Forest
# ..        ...    ...           ...  ...   ...    ...  ..  ..              ...
# 38 2020-07-07  18:00  Matchweek 34  Tue  Home      W   2   1     Norwich City
# 39 2020-11-07  12:30  Matchweek 35  Sat  Home      W   2   1    Newcastle Utd
# 40 2020-07-17  20:00  Matchweek 36  Fri  Away      L   1   3         West Ham
# 41 2020-07-21  18:00  Matchweek 37  Tue  Home      L   0   4  Manchester City
# 42 2020-07-26  16:00  Matchweek 38  Sun  Away      L   2   3          Arsenal
#
#      xg  ...  sot  dist  fk pk pkatt season             team  target  \
# 1   2.2  ...    1  18.7   1  1     1   2023  Manchester City       1
# 2   1.7  ...    7  17.5   0  0     0   2023  Manchester City       1
# 3   2.1  ...   10  16.2   1  0     0   2023  Manchester City       0
# 4   2.2  ...    5  14.1   0  0     0   2023  Manchester City       1
# 5   3.3  ...    9  14.8   0  0     0   2023  Manchester City       1
# ..  ...  ...  ...   ...  .. ..   ...    ...              ...     ...
# 38  1.2  ...    4  13.2   0  0     0   2020          Watford       1
# 39  3.4  ...    3  13.9   0  2     2   2020          Watford       1
# 40  1.5  ...    3  14.9   0  0     0   2020          Watford       0
# 41  0.1  ...    0  15.7   0  0     0   2020          Watford       0
# 42  3.7  ...    5  13.7   1  1     1   2020          Watford       0
#
#     target_2  target_3
# 1          0         0
# 2          0         0
# 3          1         0
# 4          0         0
# 5          0         0
# ..       ...       ...
# 38         0         0
# 39         0         0
# 40         0         1
# 41         0         1
# 42         0         1
#
# [3002 rows x 28 columns]

# %%
matches["venue_code"] = matches["venue"].astype("category").cat.codes

# %%
matches["opp_code"] = matches["opponent"].astype("category").cat.codes

# %%
matches["hour"] = matches["time"].str.replace(":.+", "", regex=True).astype("int")

# %%
matches["day_code"] = matches["date"].dt.dayofweek
matches
# Out:
#          date   time         round  day venue result  gf  ga         opponent  \
# 1  2022-07-08  16:30   Matchweek 1  Sun  Away      W   2   0         West Ham
# 2  2022-08-13  15:00   Matchweek 2  Sat  Home      W   4   0      Bournemouth
# 3  2022-08-21  16:30   Matchweek 3  Sun  Away      D   3   3    Newcastle Utd
# 4  2022-08-27  15:00   Matchweek 4  Sat  Home      W   4   2   Crystal Palace
# 5  2022-08-31  19:30   Matchweek 5  Wed  Home      W   6   0  Nott'ham Forest
# ..        ...    ...           ...  ...   ...    ...  ..  ..              ...
# 38 2020-07-07  18:00  Matchweek 34  Tue  Home      W   2   1     Norwich City
# 39 2020-11-07  12:30  Matchweek 35  Sat  Home      W   2   1    Newcastle Utd
# 40 2020-07-17  20:00  Matchweek 36  Fri  Away      L   1   3         West Ham
# 41 2020-07-21  18:00  Matchweek 37  Tue  Home      L   0   4  Manchester City
# 42 2020-07-26  16:00  Matchweek 38  Sun  Away      L   2   3          Arsenal
#
#      xg  ...  pkatt  season             team target target_2 target_3  \
# 1   2.2  ...      1    2023  Manchester City      1        0        0
# 2   1.7  ...      0    2023  Manchester City      1        0        0
# 3   2.1  ...      0    2023  Manchester City      0        1        0
# 4   2.2  ...      0    2023  Manchester City      1        0        0
# 5   3.3  ...      0    2023  Manchester City      1        0        0
# ..  ...  ...    ...     ...              ...    ...      ...      ...
# 38  1.2  ...      0    2020          Watford      1        0        0
# 39  3.4  ...      2    2020          Watford      1        0        0
# 40  1.5  ...      0    2020          Watford      0        0        1
# 41  0.1  ...      0    2020          Watford      0        0        1
# 42  3.7  ...      1    2020          Watford      0        0        1
#
#    venue_code  opp_code  hour  day_code
# 1           0        23    16         4
# 2           1         2    15         5
# 3           0        15    16         6
# 4           1         7    15         5
# 5           1        17    19         2
# ..        ...       ...   ...       ...
# 38          1        16    18         1
# 39          1        15    12         5
# 40          0        23    20         4
# 41          1        13    18         1
# 42          0         0    16         6
#
# [3002 rows x 32 columns]

# %%
matches
# Out:
#          date   time         round  day venue result  gf  ga         opponent  \
# 1  2022-07-08  16:30   Matchweek 1  Sun  Away      W   2   0         West Ham
# 2  2022-08-13  15:00   Matchweek 2  Sat  Home      W   4   0      Bournemouth
# 3  2022-08-21  16:30   Matchweek 3  Sun  Away      D   3   3    Newcastle Utd
# 4  2022-08-27  15:00   Matchweek 4  Sat  Home      W   4   2   Crystal Palace
# 5  2022-08-31  19:30   Matchweek 5  Wed  Home      W   6   0  Nott'ham Forest
# ..        ...    ...           ...  ...   ...    ...  ..  ..              ...
# 38 2020-07-07  18:00  Matchweek 34  Tue  Home      W   2   1     Norwich City
# 39 2020-11-07  12:30  Matchweek 35  Sat  Home      W   2   1    Newcastle Utd
# 40 2020-07-17  20:00  Matchweek 36  Fri  Away      L   1   3         West Ham
# 41 2020-07-21  18:00  Matchweek 37  Tue  Home      L   0   4  Manchester City
# 42 2020-07-26  16:00  Matchweek 38  Sun  Away      L   2   3          Arsenal
#
#      xg  ...  pkatt  season             team target target_2 target_3  \
# 1   2.2  ...      1    2023  Manchester City      1        0        0
# 2   1.7  ...      0    2023  Manchester City      1        0        0
# 3   2.1  ...      0    2023  Manchester City      0        1        0
# 4   2.2  ...      0    2023  Manchester City      1        0        0
# 5   3.3  ...      0    2023  Manchester City      1        0        0
# ..  ...  ...    ...     ...              ...    ...      ...      ...
# 38  1.2  ...      0    2020          Watford      1        0        0
# 39  3.4  ...      2    2020          Watford      1        0        0
# 40  1.5  ...      0    2020          Watford      0        0        1
# 41  0.1  ...      0    2020          Watford      0        0        1
# 42  3.7  ...      1    2020          Watford      0        0        1
#
#    venue_code  opp_code  hour  day_code
# 1           0        23    16         4
# 2           1         2    15         5
# 3           0        15    16         6
# 4           1         7    15         5
# 5           1        17    19         2
# ..        ...       ...   ...       ...
# 38          1        16    18         1
# 39          1        15    12         5
# 40          0        23    20         4
# 41          1        13    18         1
# 42          0         0    16         6
#
# [3002 rows x 32 columns]

# %%
rf = RandomForestClassifier(n_estimators=50, min_samples_split=10, random_state=1)

# %%
train = matches[matches["date"] < '2023-01-01']

# %%
test = matches[matches["date"] > '2020-01-01']

# %%
predictors = ["venue_code", "opp_code", "hour", "day_code"]

# %%
rf.fit(train[predictors], train["target"])
# Out:
# RandomForestClassifier(min_samples_split=10, n_estimators=50, random_state=1)

# %%
preds = rf.predict(test[predictors])

# %%
error = accuracy_score(test["target"], preds)

# %%
error
# Out:
# 0.7403145377828922

# %%
combined = pd.DataFrame(dict(actual=test["target"], predicted=preds))

# %%
pd.crosstab(index=combined["actual"], columns=combined["predicted"])
# Out:
# predicted     0    1
# actual
# 0          1414  183
# 1           494  516

# %%
precision_score(test["target"], preds)
# Out:
# 0.7381974248927039

# %%
grouped_matches = matches.groupby("team")

# %%
group = grouped_matches.get_group("Manchester City").sort_values("date")

# %%
def rolling_averages(group, cols, new_cols):
    group = group.sort_values("date")
    rolling_stats = group[cols].rolling(3, closed='left').mean()
    group[new_cols] = rolling_stats
    group = group.dropna(subset=new_cols)
    return group

# %%
cols = ["gf", "ga", "sh", "sot", "dist", "fk", "pk", "pkatt"]
new_cols = [f"{c}_rolling" for c in cols]

rolling_averages(group, cols, new_cols)
# Out:
#          date   time         round  day venue result  gf  ga        opponent  \
# 23 2019-07-12  17:30  Matchweek 16  Sat  Home      L   1   2  Manchester Utd
# 2  2019-08-17  17:30   Matchweek 2  Sat  Home      D   2   2       Tottenham
# 3  2019-08-25  14:00   Matchweek 3  Sun  Away      W   3   1     Bournemouth
# 4  2019-08-31  15:00   Matchweek 4  Sat  Home      W   4   0        Brighton
# 5  2019-09-14  17:30   Matchweek 5  Sat  Away      L   2   3    Norwich City
# ..        ...    ...           ...  ...   ...    ...  ..  ..             ...
# 58 2023-05-28  16:30  Matchweek 38  Sun  Away      L   0   1       Brentford
# 52 2023-06-05  15:00  Matchweek 35  Sat  Home      W   2   1    Leeds United
# 44 2023-08-04  17:30  Matchweek 30  Sat  Away      W   4   1     Southampton
# 40 2023-11-03  17:30  Matchweek 27  Sat  Away      W   1   0  Crystal Palace
# 33 2023-12-02  16:30  Matchweek 23  Sun  Home      W   3   1     Aston Villa
#
#      xg  ...  hour  day_code  gf_rolling ga_rolling sh_rolling sot_rolling  \
# 23  2.2  ...    17         4    2.000000   1.333333  20.333333    4.666667
# 2   2.9  ...    17         5    1.666667   1.666667  19.333333    5.000000
# 3   3.0  ...    14         6    1.000000   2.000000  23.666667    5.666667
# 4   1.9  ...    15         5    2.000000   1.666667  23.666667    6.666667
# 5   2.3  ...    17         5    3.000000   1.000000  21.000000    7.000000
# ..  ...  ...   ...       ...         ...        ...        ...         ...
# 58  1.6  ...    16         6    1.666667   0.333333  12.333333    3.333333
# 52  2.6  ...    15         0    0.666667   0.666667  15.000000    2.666667
# 44  2.9  ...    17         4    1.000000   1.000000  15.666667    4.000000
# 40  2.1  ...    17         4    2.000000   1.000000  15.333333    5.000000
# 33  3.3  ...    16         5    2.333333   0.666667  14.000000    5.333333
#
#    dist_rolling  fk_rolling  pk_rolling  pkatt_rolling
# 23    17.400000    1.000000    0.000000       0.000000
# 2     17.100000    1.333333    0.000000       0.000000
# 3     16.266667    1.333333    0.000000       0.000000
# 4     14.966667    0.666667    0.000000       0.000000
# 5     15.200000    0.333333    0.000000       0.000000
# ..          ...         ...         ...            ...
# 58    17.333333    0.666667    0.000000       0.000000
# 52    16.500000    0.000000    0.000000       0.000000
# 44    16.466667    0.666667    0.000000       0.333333
# 40    16.233333    0.666667    0.333333       0.666667
# 33    16.966667    1.000000    0.666667       1.000000
#
# [149 rows x 40 columns]

# %%
matches_rolling = matches.groupby("team").apply(lambda x: rolling_averages(x, cols, new_cols))

# %%
matches_rolling
# Out:
#                                  date   time         round  day venue result  \
# team
# Arsenal                 21 2019-05-12  20:15  Matchweek 15  Thu  Home      L
#                         10 2019-06-10  14:00   Matchweek 8  Sun  Home      W
#                         1  2019-08-17  12:30   Matchweek 2  Sat  Home      W
#                         2  2019-08-24  17:30   Matchweek 3  Sat  Away      L
#                         17 2019-09-11  17:30  Matchweek 12  Sat  Away      L
# ...                               ...    ...           ...  ...   ...    ...
# Wolverhampton Wanderers 43 2023-05-28  16:30  Matchweek 38  Sun  Away      L
#                         40 2023-06-05  15:00  Matchweek 35  Sat  Home      W
#                         35 2023-08-04  15:00  Matchweek 30  Sat  Home      W
#                         27 2023-11-02  15:00  Matchweek 23  Sat  Away      W
#                         32 2023-12-03  16:30  Matchweek 27  Sun  Away      L
#
#                             gf  ga        opponent   xg  ...  hour  day_code  \
# team                                                     ...
# Arsenal                 21   1   2        Brighton  0.9  ...    20         6
#                         10   1   0     Bournemouth  1.2  ...    14         0
#                         1    2   1         Burnley  0.8  ...    12         5
#                         2    1   3       Liverpool  1.0  ...    17         5
#                         17   0   2  Leicester City  1.0  ...    17         2
# ...                         ..  ..             ...  ...  ...   ...       ...
# Wolverhampton Wanderers 43   0   5         Arsenal  0.5  ...    16         6
#                         40   1   0     Aston Villa  0.8  ...    15         0
#                         35   1   0         Chelsea  0.6  ...    15         4
#                         27   2   1     Southampton  0.8  ...    15         3
#                         32   1   2   Newcastle Utd  1.1  ...    16         6
#
#                             gf_rolling ga_rolling sh_rolling sot_rolling  \
# team
# Arsenal                 21    1.666667   1.666667  17.000000    5.666667
#                         10    1.333333   1.666667  12.333333    4.666667
#                         1     1.000000   1.000000  11.333333    3.666667
#                         2     1.333333   1.000000  13.000000    5.333333
#                         17    1.333333   1.333333  12.000000    4.666667
# ...                                ...        ...        ...         ...
# Wolverhampton Wanderers 43    0.333333   3.000000   9.333333    2.333333
#                         40    0.333333   2.666667   8.000000    1.666667
#                         35    0.666667   2.000000   8.333333    2.333333
#                         27    0.666667   1.666667   7.000000    2.000000
#                         32    1.333333   0.333333   8.666667    2.333333
#
#                            dist_rolling  fk_rolling  pk_rolling  pkatt_rolling
# team
# Arsenal                 21    15.833333    0.666667    0.333333       0.333333
#                         10    15.200000    0.333333    0.333333       0.333333
#                         1     15.466667    0.333333    0.000000       0.000000
#                         2     16.733333    0.333333    0.000000       0.000000
#                         17    17.666667    0.333333    0.000000       0.000000
# ...                                 ...         ...         ...            ...
# Wolverhampton Wanderers 43    15.700000    0.333333    0.000000       0.000000
#                         40    14.366667    0.666667    0.000000       0.000000
#                         35    16.733333    0.666667    0.000000       0.000000
#                         27    18.833333    0.333333    0.000000       0.000000
#                         32    20.166667    0.000000    0.000000       0.000000
#
# [2924 rows x 40 columns]

# %%
matches_rolling = matches_rolling.droplevel('team')

# %%
matches_rolling
# Out:
#          date   time         round  day venue result  gf  ga        opponent  \
# 21 2019-05-12  20:15  Matchweek 15  Thu  Home      L   1   2        Brighton
# 10 2019-06-10  14:00   Matchweek 8  Sun  Home      W   1   0     Bournemouth
# 1  2019-08-17  12:30   Matchweek 2  Sat  Home      W   2   1         Burnley
# 2  2019-08-24  17:30   Matchweek 3  Sat  Away      L   1   3       Liverpool
# 17 2019-09-11  17:30  Matchweek 12  Sat  Away      L   0   2  Leicester City
# ..        ...    ...           ...  ...   ...    ...  ..  ..             ...
# 43 2023-05-28  16:30  Matchweek 38  Sun  Away      L   0   5         Arsenal
# 40 2023-06-05  15:00  Matchweek 35  Sat  Home      W   1   0     Aston Villa
# 35 2023-08-04  15:00  Matchweek 30  Sat  Home      W   1   0         Chelsea
# 27 2023-11-02  15:00  Matchweek 23  Sat  Away      W   2   1     Southampton
# 32 2023-12-03  16:30  Matchweek 27  Sun  Away      L   1   2   Newcastle Utd
#
#      xg  ...  hour  day_code  gf_rolling ga_rolling sh_rolling sot_rolling  \
# 21  0.9  ...    20         6    1.666667   1.666667  17.000000    5.666667
# 10  1.2  ...    14         0    1.333333   1.666667  12.333333    4.666667
# 1   0.8  ...    12         5    1.000000   1.000000  11.333333    3.666667
# 2   1.0  ...    17         5    1.333333   1.000000  13.000000    5.333333
# 17  1.0  ...    17         2    1.333333   1.333333  12.000000    4.666667
# ..  ...  ...   ...       ...         ...        ...        ...         ...
# 43  0.5  ...    16         6    0.333333   3.000000   9.333333    2.333333
# 40  0.8  ...    15         0    0.333333   2.666667   8.000000    1.666667
# 35  0.6  ...    15         4    0.666667   2.000000   8.333333    2.333333
# 27  0.8  ...    15         3    0.666667   1.666667   7.000000    2.000000
# 32  1.1  ...    16         6    1.333333   0.333333   8.666667    2.333333
#
#    dist_rolling  fk_rolling  pk_rolling  pkatt_rolling
# 21    15.833333    0.666667    0.333333       0.333333
# 10    15.200000    0.333333    0.333333       0.333333
# 1     15.466667    0.333333    0.000000       0.000000
# 2     16.733333    0.333333    0.000000       0.000000
# 17    17.666667    0.333333    0.000000       0.000000
# ..          ...         ...         ...            ...
# 43    15.700000    0.333333    0.000000       0.000000
# 40    14.366667    0.666667    0.000000       0.000000
# 35    16.733333    0.666667    0.000000       0.000000
# 27    18.833333    0.333333    0.000000       0.000000
# 32    20.166667    0.000000    0.000000       0.000000
#
# [2924 rows x 40 columns]

# %%
matches_rolling.index = range(matches_rolling.shape[0])
matches_rolling
# Out:
#            date   time         round  day venue result  gf  ga  \
# 0    2019-05-12  20:15  Matchweek 15  Thu  Home      L   1   2
# 1    2019-06-10  14:00   Matchweek 8  Sun  Home      W   1   0
# 2    2019-08-17  12:30   Matchweek 2  Sat  Home      W   2   1
# 3    2019-08-24  17:30   Matchweek 3  Sat  Away      L   1   3
# 4    2019-09-11  17:30  Matchweek 12  Sat  Away      L   0   2
# ...         ...    ...           ...  ...   ...    ...  ..  ..
# 2919 2023-05-28  16:30  Matchweek 38  Sun  Away      L   0   5
# 2920 2023-06-05  15:00  Matchweek 35  Sat  Home      W   1   0
# 2921 2023-08-04  15:00  Matchweek 30  Sat  Home      W   1   0
# 2922 2023-11-02  15:00  Matchweek 23  Sat  Away      W   2   1
# 2923 2023-12-03  16:30  Matchweek 27  Sun  Away      L   1   2
#
#             opponent   xg  ...  hour  day_code  gf_rolling ga_rolling  \
# 0           Brighton  0.9  ...    20         6    1.666667   1.666667
# 1        Bournemouth  1.2  ...    14         0    1.333333   1.666667
# 2            Burnley  0.8  ...    12         5    1.000000   1.000000
# 3          Liverpool  1.0  ...    17         5    1.333333   1.000000
# 4     Leicester City  1.0  ...    17         2    1.333333   1.333333
# ...              ...  ...  ...   ...       ...         ...        ...
# 2919         Arsenal  0.5  ...    16         6    0.333333   3.000000
# 2920     Aston Villa  0.8  ...    15         0    0.333333   2.666667
# 2921         Chelsea  0.6  ...    15         4    0.666667   2.000000
# 2922     Southampton  0.8  ...    15         3    0.666667   1.666667
# 2923   Newcastle Utd  1.1  ...    16         6    1.333333   0.333333
#
#      sh_rolling sot_rolling dist_rolling  fk_rolling  pk_rolling  \
# 0     17.000000    5.666667    15.833333    0.666667    0.333333
# 1     12.333333    4.666667    15.200000    0.333333    0.333333
# 2     11.333333    3.666667    15.466667    0.333333    0.000000
# 3     13.000000    5.333333    16.733333    0.333333    0.000000
# 4     12.000000    4.666667    17.666667    0.333333    0.000000
# ...         ...         ...          ...         ...         ...
# 2919   9.333333    2.333333    15.700000    0.333333    0.000000
# 2920   8.000000    1.666667    14.366667    0.666667    0.000000
# 2921   8.333333    2.333333    16.733333    0.666667    0.000000
# 2922   7.000000    2.000000    18.833333    0.333333    0.000000
# 2923   8.666667    2.333333    20.166667    0.000000    0.000000
#
#       pkatt_rolling
# 0          0.333333
# 1          0.333333
# 2          0.000000
# 3          0.000000
# 4          0.000000
# ...             ...
# 2919       0.000000
# 2920       0.000000
# 2921       0.000000
# 2922       0.000000
# 2923       0.000000
#
# [2924 rows x 40 columns]

# %%
def make_predictions(data, predictors):
    train = data[data["date"] < '2023-01-01']
    test = data[data["date"] > '2023-01-01']
    rf.fit(train[predictors], train["target"])
    preds = rf.predict(test[predictors])
    combined = pd.DataFrame(dict(actual=test["target"], predicted=preds), index=test.index)
    error = precision_score(test["target"], preds)
    return combined, error
